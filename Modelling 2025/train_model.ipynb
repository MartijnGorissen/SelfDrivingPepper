# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    for device in range(torch.cuda.device_count()):
        print(f"CUDA Device Name {device + 1}: {torch.cuda.get_device_name(device)}")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
# Out:
# CUDA Available: True
# CUDA Device Name 1: NVIDIA GeForce RTX 4080 SUPER
# Number of GPUs: 1

# %%
from ultralytics import YOLO
import torch
import datetime

model_path = 'model7.pt'
print(f"Loading pre-trained model from: {model_path}")
model = YOLO(model_path)
print("Model loaded successfully.")

data_yaml_path = 'data.yaml' 

epochs_to_train = 500
image_size = 640
batch_size = 128
run_name = f'{datetime.datetime.now().strftime("%m_%d_%H%M%S")}'

print("Starting training...")
results = model.train(
    data=data_yaml_path,
    epochs=epochs_to_train,
    imgsz=image_size,
    batch=batch_size,
    name=run_name,
    workers=8,
    device=0
)
print("Training finished.")
print(f"Results saved to: {results.save_dir}")
# Out:
# Loading pre-trained model from: model7.pt
# Model loaded successfully.
# Starting training...
# New https://pypi.org/project/ultralytics/8.3.144 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.136 🚀 Python-3.10.12 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4080 SUPER, 15955MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=128, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=500, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=model7.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=05_24_115231, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=None, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=runs/detect/05_24_115231, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    752482  ultralytics.nn.modules.head.Detect           [6, [64, 128, 256]]
# YOLOv8n summary: 129 layers, 3,012,018 parameters, 3,012,002 gradients, 8.2 GFLOPs
#
# Transferred 355/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 2107.0±767.9 MB/s, size: 50.7 KB)
# train: Scanning /workspace/SelfDrivingPepper/Modelling 2025/datasets/dataset/train/labels.cache... 19140 images, 14302 backgrounds, 0 corrupt: 100%|██████████| 19140/19140 [00:00<?, ?it/s]
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1231.2±808.5 MB/s, size: 72.2 KB)
# val: Scanning /workspace/SelfDrivingPepper/Modelling 2025/datasets/dataset/val/labels.cache... 1829 images, 690 backgrounds, 0 corrupt: 100%|██████████| 1829/1829 [00:00<?, ?it/s]
# Plotting labels to runs/detect/05_24_115231/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: SGD(lr=0.01, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to runs/detect/05_24_115231
# Starting training for 500 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/500      14.7G      1.137     0.4932     0.9471         36        640: 100%|██████████| 150/150 [00:47<00:00,  3.14it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.64it/s]
#                    all       1829       1317      0.922       0.93      0.955      0.675
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/500      14.1G      1.121     0.5085     0.9365         50        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.74it/s]
#                    all       1829       1317      0.941      0.895      0.951      0.642
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/500      14.1G      1.174     0.5673     0.9463         42        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]
#                    all       1829       1317      0.878      0.843      0.879      0.563
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/500      14.2G      1.234     0.6364     0.9648         42        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.89it/s]
#                    all       1829       1317      0.887      0.764      0.841      0.511
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/500      14.1G      1.231     0.6365      0.968         56        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.70it/s]
#                    all       1829       1317      0.829       0.82      0.821      0.496
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/500      14.1G      1.235     0.6361     0.9625         38        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.65it/s]
#                    all       1829       1317      0.854      0.738      0.855      0.515
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/500      14.1G      1.239     0.6456     0.9713         43        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.39it/s]
#                    all       1829       1317      0.882      0.807       0.83      0.419
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/500      14.1G      1.227     0.6301     0.9635         51        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.62it/s]
#                    all       1829       1317      0.873      0.815      0.838      0.495
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/500      14.2G      1.215     0.6264     0.9621         34        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.70it/s]
#                    all       1829       1317      0.858      0.781      0.828      0.504
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/500      14.1G      1.215     0.6256       0.96         48        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.76it/s]
#                    all       1829       1317      0.814      0.806      0.831       0.51
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/500      14.1G      1.216     0.6203     0.9629         79        640:  71%|███████▏  | 107/150 [00:33<00:13,  3.18it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7e845bf8e9e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1663, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1646, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7e845bf8e9e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1663, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1646, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#      11/500      14.1G      1.214     0.6195     0.9637         73        640:  73%|███████▎  | 109/150 [00:34<00:12,  3.18it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7e845bf8e9e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1663, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1646, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7e845bf8e9e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1663, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1646, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#      11/500      14.1G      1.214     0.6196     0.9645         81        640:  74%|███████▍  | 111/150 [00:34<00:12,  3.18it/s]Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7e845bf8e9e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1663, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1646, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7e845bf8e9e0>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1663, in __del__
#     self._shutdown_workers()
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py", line 1646, in _shutdown_workers
#     if w.is_alive():
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
#
0.493
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/500      14.2G      1.146     0.5679     0.9409         37        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.80it/s]
#                    all       1829       1317      0.822      0.778      0.814      0.489
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/500      14.1G      1.141     0.5695     0.9377         47        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.83it/s]
#                    all       1829       1317      0.822      0.781      0.817      0.493
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/500      14.1G      1.142     0.5713     0.9458         60        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.83it/s]
#                    all       1829       1317      0.819      0.765      0.815       0.49
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/500      14.1G      1.143     0.5711     0.9399         57        640: 100%|██████████| 150/150 [00:46<00:00,  3.20it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.81it/s]
#                    all       1829       1317      0.808      0.771      0.813      0.489
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/500      14.1G      1.138     0.5652     0.9431         58        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.81it/s]
#                    all       1829       1317      0.815      0.758      0.815       0.49
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/500      14.1G       1.13     0.5653     0.9372         38        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.81it/s]
#                    all       1829       1317        0.8      0.776      0.818      0.497
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/500      14.1G      1.147     0.5733      0.946         27        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.82it/s]
#                    all       1829       1317      0.808      0.781      0.818      0.497
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/500      14.1G      1.136     0.5675     0.9396         28        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.80it/s]
#                    all       1829       1317      0.829      0.762      0.816      0.493
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/500      14.1G      1.125     0.5677     0.9383         47        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.82it/s]
#                    all       1829       1317      0.813      0.784       0.82      0.499
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/500      14.1G      1.129     0.5595     0.9362         36        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.83it/s]
#                    all       1829       1317      0.817      0.787      0.825      0.501
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/500      14.2G      1.149      0.568     0.9476         43        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.83it/s]
#                    all       1829       1317      0.819      0.789      0.829      0.504
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/500      14.2G      1.131     0.5637     0.9415         35        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.80it/s]
#                    all       1829       1317      0.821      0.796      0.828      0.505
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/500      14.2G      1.139     0.5616     0.9411         46        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.82it/s]
#                    all       1829       1317      0.824      0.796      0.829        0.5
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/500      14.1G      1.138     0.5592     0.9419         26        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.84it/s]
#                    all       1829       1317      0.808      0.801      0.828      0.503
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/500      14.2G      1.126     0.5613     0.9373         36        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.84it/s]
#                    all       1829       1317       0.81      0.798      0.823      0.501
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/500      14.1G      1.129     0.5592      0.937         38        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.83it/s]
#                    all       1829       1317      0.802      0.797      0.821        0.5
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/500      14.1G      1.129     0.5647     0.9412         41        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.82it/s]
#                    all       1829       1317      0.809      0.789      0.821      0.499
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/500      14.1G      1.139     0.5605     0.9394         25        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.83it/s]
#                    all       1829       1317      0.828      0.779      0.823      0.498
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/500      14.1G      1.133      0.558     0.9366         44        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.83it/s]
#                    all       1829       1317      0.824      0.779      0.823      0.496
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/500      14.2G      1.143     0.5631     0.9424         46        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.82it/s]
#                    all       1829       1317      0.825      0.783      0.825      0.497
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/500      14.2G      1.125     0.5593     0.9353         51        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.80it/s]
#                    all       1829       1317      0.831       0.78      0.823      0.498
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/500      14.1G      1.126     0.5591     0.9361         41        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.83it/s]
#                    all       1829       1317      0.839       0.78      0.824      0.499
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/500      14.1G      1.133     0.5644     0.9342         44        640: 100%|██████████| 150/150 [00:47<00:00,  3.19it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.81it/s]
#                    all       1829       1317      0.839      0.778      0.822      0.497
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/500      14.1G      1.129       0.56     0.9321         54        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.82it/s]
#                    all       1829       1317      0.837      0.777      0.823      0.497
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     101/500      14.2G      1.125     0.5559     0.9383         59        640: 100%|██████████| 150/150 [00:47<00:00,  3.18it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  3.82it/s]
#                    all       1829       1317      0.826       0.78      0.821      0.495
# EarlyStopping: Training stopped early as no improvement observed in last 100 epochs. Best results observed at epoch 1, best model saved as best.pt.
# To update EarlyStopping(patience=100) pass a new patience value, i.e. `patience=300` or use `patience=0` to disable EarlyStopping.
# 101 epochs completed in 1.393 hours.
# Optimizer stripped from runs/detect/05_24_115231/weights/last.pt, 6.2MB
# Optimizer stripped from runs/detect/05_24_115231/weights/best.pt, 6.2MB
#
# Validating runs/detect/05_24_115231/weights/best.pt...
# Ultralytics 8.3.136 🚀 Python-3.10.12 torch-2.7.0+cu126 CUDA:0 (NVIDIA GeForce RTX 4080 SUPER, 15955MiB)
# YOLOv8n summary (fused): 72 layers, 3,006,818 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 8/8 [00:02<00:00,  2.81it/s]
#                    all       1829       1317      0.922       0.93      0.955      0.675
#                   auto        237        237      0.786      0.987      0.968      0.823
#                  groen         37         37          1      0.995      0.995      0.685
#                linksaf        488        488      0.981      0.984      0.993      0.759
#                   rood        305        305      0.874      0.948      0.955      0.553
#          snelheidsbord         67         91      0.913      0.694      0.838      0.543
#                   stop        159        159      0.976      0.975      0.982       0.69
# Speed: 0.0ms preprocess, 0.3ms inference, 0.0ms loss, 0.4ms postprocess per image
# Results saved to runs/detect/05_24_115231
# Training finished.
# Results saved to: runs/detect/05_24_115231
